# %%
# import packages
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.bookswagon.com/')
response
# Out:
# <Response [200]>

# %%
html_data = response.text

# %%
data = BeautifulSoup(html_data, 'html.parser')
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, minimum-scale=1" name="viewport"/>
#   <meta content="97nrVG-X7jGxGUZWq_OtuBwwtuYeB1Ai3oGPnvx4-wM" name="google-site-verification"/>
#   <title>
#    Online Bookstore | Buy Books Online | Read Books Online
#   </title>
#   <meta content="R9odRi1RDuadeaplaqkNV8gXMCW33SBEJEUCUDPU8y0" name="google-site-verification"/>
#   <script>
#    var head = document.getElementsByTagName('HEAD')[0];
#         // Create new link Element
#         var link4 = document.createElement('link');
#         // set the attributes for link element
#         link4.rel = 'stylesheet';
#
#         link4.type = 'text/css';
#
#         link4.href = 'https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick.min.css';
#         head.appendChild(link4);
#
#
#         // Create new link Element
#         var link7 = document.createElement('link');
# ...

# %%
## Print Link for all books titles

l1,l2,l3=[],[],[]
all_books_titles = data.find_all(class_='booktitle')
for i in all_books_titles:
    l1.append(i.string)
print(l1)

all_books_authors = data.find_all(class_='author')
for j in all_books_authors:
    l2.append(j.string)
print(l2)

all_books_price = data.find_all(class_='actualprice')
for k in all_books_price:
    l3.append(k.string)
print(l3)

print(len(l1))
print(len(l2))
print(len(l3))
l3 = l3[:-1]
print(len(l3))
# Out:
# ['Atomic Habits', 'The Psychology of Money', 'Ikigai', 'Word Power Made Easy', 'My First Library: Boxset of 10 Board Books for Kids', 'Rich Dad Poor Dad', "Grandma's Bag of Stories", "Life's Amazing Secrets: How to Find Balance and Purpose in your life", 'It Ends with Us', 'Quantitative Aptitude for Competitive Examinations', 'Alchemist', 'Quantitative Aptitude for Competitive Examinations', 'The Intelligent Investor', 'The Diary Of A Young Girl', 'Wuthering Heights', 'Socho Aur Amir Ho Jao (Think And Grow Rich - Hindi)', 'Autobiography Of A Yogi', 'Metamorphosis', 'The Art Of War', 'The Origin of Species', 'The Unusual Billionaires', 'Rich Dad Poor Dad', 'It Ends with Us', 'The Seven Husbands of Evelyn Hugo', 'Ugly Love', 'The Kid Who Came From Space', "Children'S Encyclopedia - Scientists, Inventions and Discoveries", 'Shoe Dog', 'November 9', "Where Is Baby's Belly Button?", 'Secret', 'The Midnight Library', 'Magic', 'Red, White & Royal Blue', 'The Letters of Vincent Van Gogh', 'N
# ...

# %%
import pandas as pd

dictionary = {'title':l1,'author':l2,'price':l3}
dataset = pd.DataFrame(dictionary)
dataset.head()
# Out:
#                                                title  \
# 0                                      Atomic Habits
# 1                            The Psychology of Money
# 2                                             Ikigai
# 3                               Word Power Made Easy
# 4  My First Library: Boxset of 10 Board Books for...
#
#                          author price
# 0                   James Clear  ₹551
# 1                 Morgan Housel  ₹295
# 2             Francesc Miralles  ₹391
# 3                  Norman Lewis  ₹105
# 4  Wonder House Books Editorial  ₹273

# %%
dataset.to_csv('books.csv')
